# %% [markdown]
# <a href="https://colab.research.google.com/github/wongalex349/BigDataAnalytics/blob/master/PandasAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
import pandas as pd

# %%
from google.colab import drive #importing onto google drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
base = '/content/drive/My Drive/Colab Notebooks/8358_1.csv'
file = pd.read_csv(base)

# %%
file.head(50)
# Out:
#                       id  ...        province
# 0   AVwc_6KEIN2L1WUfrKAH  ...              OR
# 1   AVwc_6KEIN2L1WUfrKAH  ...              OR
# 2   AVwc_6qRByjofQCxkcxw  ...       Brentwood
# 3   AVwc_6qRByjofQCxkcxw  ...       Brentwood
# 4   AVwc_6qRByjofQCxkcxw  ...       Brentwood
# 5   AVwc_6qRByjofQCxkcxw  ...       Brentwood
# 6   AVwc_6qRByjofQCxkcxw  ...       Brentwood
# 7   AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 8   AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 9   AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 10  AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 11  AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 12  AVwc_7d_IN2L1WUfrKNN  ...       Los Feliz
# 13  AVwc_8WAByjofQCxkdDA  ...              TX
# 14  AVwc_abAIN2L1WUfrEps  ...              MA
# 15  AVwc_abAIN2L1WUfrEps  ...              MA
# 16  AVwc_dHKkufWRAb51Kei  ...              UT
# 17  AVwc_dHKkufWRAb51Kei  ...              UT
# 18  AVwc_dHKkufWRAb51Kei  ...              UT
# ...

# %%
file.tail(50)
# Out:
#                         id  ...               province
# 3460  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3461  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3462  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3463  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3464  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3465  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3466  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3467  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3468  AVweT3Ur_7pvs4fzB3jP  ...                     IL
# 3469  AVweTiNckufWRAb5BxSk  ...                   Wilm
# 3470  AVweTiNckufWRAb5BxSk  ...                   Wilm
# 3471  AVweTKY6kufWRAb5BuJ4  ...  Mount Laurel Township
# 3472  AVweTZpH_7pvs4fzBz2d  ...                     IN
# 3473  AVweTZpH_7pvs4fzBz2d  ...                     IN
# 3474  AVweTZpH_7pvs4fzBz2d  ...                     IN
# 3475  AVweU1AukufWRAb5B8eR  ...          Pembroke Pnes
# ...

# %%
file.describe()
# Out:
#           latitude    longitude  ...  priceRangeMin  priceRangeMax
# count  3510.000000  3510.000000  ...    1557.000000    1557.000000
# mean     38.555114   -87.472055  ...      15.597945      36.566474
# std       4.651092    16.430008  ...      18.495854      21.737839
# min      18.411826  -157.837461  ...       0.000000      12.000000
# 25%      35.769852   -94.202573  ...       0.000000      30.000000
# 50%      40.020710   -81.675414  ...      25.000000      40.000000
# 75%      41.455179   -74.743820  ...      25.000000      40.000000
# max      64.854370   -66.024871  ...     347.000000     666.000000
#
# [8 rows x 6 columns]

# %%
file[['categories','menus.amountMax']].head(10)
# Out:
#                        categories  menus.amountMax
# 0                     Pizza Place            22.50
# 1                     Pizza Place            18.95
# 2  American Restaurant,Bar,Bakery            12.00
# 3  American Restaurant,Bar,Bakery            13.00
# 4  American Restaurant,Bar,Bakery            13.00
# 5  American Restaurant,Bar,Bakery            15.00
# 6  American Restaurant,Bar,Bakery            15.00
# 7                     Pizza Place            10.99
# 8                     Pizza Place            11.99
# 9                     Pizza Place            16.99

# %%
file[5:10].head(10)
# Out:
#                      id               address  ... priceRangeMax   province
# 5  AVwc_6qRByjofQCxkcxw  148 S Barrington Ave  ...          55.0  Brentwood
# 6  AVwc_6qRByjofQCxkcxw  148 S Barrington Ave  ...          55.0  Brentwood
# 7  AVwc_7d_IN2L1WUfrKNN   5142 Hollywood Blvd  ...           NaN  Los Feliz
# 8  AVwc_7d_IN2L1WUfrKNN   5142 Hollywood Blvd  ...           NaN  Los Feliz
# 9  AVwc_7d_IN2L1WUfrKNN   5142 Hollywood Blvd  ...           NaN  Los Feliz
#
# [5 rows x 21 columns]

# %%
file_sub = file[file['menus.amountMax'] > 20]
file_sub.head(10)
# Out:
#                        id  ...               province
# 0    AVwc_6KEIN2L1WUfrKAH  ...                     OR
# 59   AVwc0cXJkufWRAb5zW_a  ...                     NV
# 85   AVwc16D3_7pvs4fzziP1  ...          Lawrenceville
# 86   AVwc16D3_7pvs4fzziP1  ...          Lawrenceville
# 185  AVwc4s7NIN2L1WUfp9WM  ...                     NY
# 194  AVwc59P_ByjofQCxjeDD  ...                     NJ
# 226  AVwc-6fkkufWRAb51EsV  ...  Village Of Wellington
# 348  AVwcfDVeIN2L1WUfldUn  ...                     CA
# 349  AVwcfDVeIN2L1WUfldUn  ...                     CA
# 350  AVwcfDVeIN2L1WUfldUn  ...                     CA
#
# [10 rows x 21 columns]

# %%
file[file.isnull().any(axis = 1)].head()
# Out:
#                      id  ...   province
# 0  AVwc_6KEIN2L1WUfrKAH  ...         OR
# 1  AVwc_6KEIN2L1WUfrKAH  ...         OR
# 2  AVwc_6qRByjofQCxkcxw  ...  Brentwood
# 3  AVwc_6qRByjofQCxkcxw  ...  Brentwood
# 4  AVwc_6qRByjofQCxkcxw  ...  Brentwood
#
# [5 rows x 21 columns]

# %%
doub = file[['menus.amountMax','menus.amountMin','priceRangeMax','priceRangeMin']] * 2.0
doub.head(10)
# Out:
#    menus.amountMax  menus.amountMin  priceRangeMax  priceRangeMin
# 0            45.00            31.00            NaN            NaN
# 1            37.90            37.90            NaN            NaN
# 2            24.00            24.00          110.0          100.0
# 3            26.00            26.00          110.0          100.0
# 4            26.00            26.00          110.0          100.0
# 5            30.00            30.00          110.0          100.0
# 6            30.00            30.00          110.0          100.0
# 7            21.98            15.98            NaN            NaN
# 8            23.98            15.98            NaN            NaN
# 9            33.98            23.98            NaN            NaN

# %%
sort = doub.sort_values(by = 'menus.amountMax')
sort.head(10)
# Out:
#       menus.amountMax  menus.amountMin  priceRangeMax  priceRangeMin
# 1869             0.00             0.00            NaN            NaN
# 2773             0.50             0.50            NaN            NaN
# 1069             0.70             0.70           80.0           50.0
# 1725             1.18             1.18            NaN            NaN
# 411              1.18             1.18            NaN            NaN
# 1688             1.18             1.18            NaN            NaN
# 1233             1.18             1.18            NaN            NaN
# 2413             1.18             1.18            NaN            NaN
# 884              1.38             1.38            NaN            NaN
# 2739             1.50             1.50            NaN            NaN

# %%
file.groupby(['id'], sort = True)[['menus.amountMax','menus.amountMin','priceRangeMax','priceRangeMin']].mean()
# Out:
#                       menus.amountMax  ...  priceRangeMin
# id                                     ...
# AVwc-0zw_7pvs4fz1AjD         8.083333  ...           25.0
# AVwc-6fkkufWRAb51EsV        65.640000  ...           25.0
# AVwc-7OI_7pvs4fz1Boz        11.333333  ...            0.0
# AVwc-Biq_7pvs4fz04TA        14.000000  ...            0.0
# AVwc-IY__7pvs4fz05S8         5.000000  ...            NaN
# AVwc-XbYIN2L1WUfq5wN         7.120000  ...           25.0
# AVwc-YZE_7pvs4fz071n         7.886250  ...            NaN
# AVwc-ln6_7pvs4fz0-I5        16.750000  ...           25.0
# AVwc-tBG_7pvs4fz0_PS         1.000000  ...            0.0
# AVwc05XuByjofQCxinyc              NaN  ...            NaN
# AVwc0Be1kufWRAb5zSVB         8.000000  ...            NaN
# AVwc0N-0ByjofQCxif90         8.950000  ...            0.0
# AVwc0UfGkufWRAb5zVuE         4.730000  ...            NaN
# AVwc0Wtp_7pvs4fzzSbm        15.950000  ...           25.0
# ...
